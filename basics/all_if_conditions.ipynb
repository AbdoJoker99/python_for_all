# %% [markdown]
# # All If Conditions Extracted from Project Files
#
# Consolidated if-condition code and examples filtered from all analyzed notebooks and .py files.
#
# **Sources:** basics/python_conditionals_loops.ipynb (primary), python_loops_complete.ipynb, python_functions.ipynb, oop/python_classes.ipynb
#
# Run cells to test.

# %% [markdown]
# ## From basics/python_conditionals_loops.ipynb

# %%
# Equality
car = 'bmw'
print(car == 'bmw')   # True
print(car == 'audi')  # False

# Case insensitive
car = 'Audi'
print(car.lower() == 'audi')  # True

# Inequality
topping = 'mushrooms'
print(topping != 'anchovies')  # True

# %%
# Numerical
age = 19
print(age < 21)      # True
print(age <= 21)     # True
print(age > 21)      # False
print(age >= 21)     # False

# %%
# Multiple conditions
age_0 = 22
age_1 = 18
print(age_0 >= 21 and age_1 >= 21)  # False
print(age_0 >= 21 or age_1 >= 21)   # True

# %%
# Simple if
age = 19
if age >= 18:
    print("You're old enough to vote!")

# %%
# if-else
age = 17
if age >= 18:
    print("You're old enough to vote!")
else:
    print("You can't vote yet.")

# %%
# if-elif-else chain
age = 12
if age < 4:
    price = 0
elif age < 18:
    price = 5
else:
    price = 10
print(f"Your cost is ${price}.")

# %%
# Lists
players = ['al', 'bea', 'cyn', 'dale']
print('al' in players)      # True
print('eric' in players)    # False

# %% [markdown]
# ## From basics/python_loops_complete.ipynb (If in loops)

# %%
# break
for num in range(10):
    if num == 5:
        break
    print(num)

# %%
# continue
for num in range(5):
    if num % 2 == 0:
        continue
    print(f"Odd: {num}")

# %%
# Filtering
votes = [18, 25, 16, 30]
can_vote = []
for age in votes:
    if age >= 18:
        can_vote.append(age)
print(can_vote)

# %% [markdown]
# ## From basics/python_functions.ipynb

# %%
def build_person(first, last, age=None):
    person = {'first': first, 'last': last}
    if age:
        person['age'] = age
    return person

musician = build_person('jimi', 'hendrix', 27)
print(musician)

# %% [markdown]
# ## From oop/python_classes.ipynb

# %%
class Car:
    def __init__(self):
        self.fuel_capacity = 15
        self.fuel_level = 0

    def update_fuel_level(self, new_level):
        if new_level <= self.fuel_capacity:
            self.fuel_level = new_level
        else:
            print("The tank can't hold that much!")

my_car = Car()
my_car.update_fuel_level(10)
print(my_car.fuel_level)
my_car.update_fuel_level(20)

# %%
class Car:
    def __init__(self):
        self.fuel_capacity = 15
        self.fuel_level = 0

    def add_fuel(self, amount):
        if (self.fuel_level + amount <= self.fuel_capacity):
            self.fuel_level += amount
            print("Added fuel.")
        else:
            print("The tank won't hold that much.")

my_car = Car()
my_car.add_fuel(10)
print(f"Fuel level: {my_car.fuel_level}")
my_car.add_fuel(10)

# %% [markdown]
# ## Summary
#
# All if-condition content filtered and runnable. No other significant if blocks in analyzed files.
