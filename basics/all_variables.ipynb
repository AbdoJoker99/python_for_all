# %% [markdown]
# # All Variable Names & Rules Filtered/Examples from Project
#
# **Rules:** Letter/_, no number start, alphanumeric+_, case-sensitive, no keywords.

# %% [markdown]
# ## Valid Examples from Files

# %%
# Short names
x = 5
y = 10
print(x, y)

# Descriptive
age = 25
car_name = 'audi'
total_volume = 100
print(age, car_name, total_volume)

# %%
# From project files
car = 'bmw'  # Valid
alien_0 = {'color': 'green'}  # _ and numbers OK after letter
age_0 = 22
age_1 = 18
print(car, alien_0, age_0, age_1)

# %% [markdown]
# ## Case Sensitivity

# %%
age = 25
Age = 30
AGE = 35
print(age, Age, AGE)  # 3 different vars

# %% [markdown]
# ## Invalid Examples (Errors)

# %%
# try:
#     _2var = 1  # Starts _ OK
#     2var_ = 2  # ERROR: starts number
#     var@ = 3  # ERROR: special char
#     for = 4  # ERROR: keyword
# except SyntaxError as e:
#     print(e)

print("See rules - no numbers first, alphanumeric/_ only")

# %% [markdown]
# ## Project Variable Examples
#
# (Common patterns)

# %%
# snake_case common in Python
unprinted_designs = ['phone_case', 'pendant']
completed_models = []
current_design = unprinted_designs.pop()

print(current_design)

# %% [markdown]
# ## Keywords (Cannot Use)

# %%
import keyword
print(keyword.kwlist[:10], '...')  # See all

# %% [markdown]
# ## Summary
#
# ✅ Start letter/_
# ✅ Alphanumeric + _ only
# ✅ Case-sensitive
# ❌ No keywords/numbers first/special chars
#
# Use descriptive snake_case (PEP 8).
